# %%
import pandas as pd

# %%
df2022=pd.read_csv("2022_mass_shootings.csv")
df=pd.read_csv("mass_shootings.csv")
df
# Out:
#       Incident ID      Incident Date       State  City Or County  \
# 0          271363  December 29, 2014   Louisiana     New Orleans
# 1          269679  December 27, 2014  California     Los Angeles
# 2          270036  December 27, 2014  California      Sacramento
# 3          269167  December 26, 2014    Illinois  East St. Louis
# 4          268598  December 24, 2014    Missouri     Saint Louis
# ...           ...                ...         ...             ...
# 3604       274867    January 6, 2015     Florida           Miami
# 3605       273535    January 4, 2015    Virginia         Roanoke
# 3606       273397    January 4, 2015       Texas          Dallas
# 3607       273965    January 2, 2015     Georgia        Savannah
# 3608       272016    January 1, 2015   Tennessee         Memphis
#
#                                   Address  # Killed  # Injured
# 0                     Poydras and Bolivar         0          4
# ...

# %%
df2022
# Out:
#      Incident ID Incident Date           State City Or County  \
# 0        2358329     12-Jul-22   Massachusetts         Boston
# 1        2358053     11-Jul-22     Mississippi        Jackson
# 2        2356813     10-Jul-22           Texas          Alvin
# 3        2356705     10-Jul-22        Illinois     Crest Hill
# 4        2356327     10-Jul-22        Missouri    Kansas City
# ..           ...           ...             ...            ...
# 328      2201641      1-Jan-22       Wisconsin        Kenosha
# 329      2202001      1-Jan-22        Illinois         Peoria
# 330      2201876      1-Jan-22  South Carolina         Dillon
# 331      2201848      1-Jan-22         Indiana     South Bend
# 332      2201677      1-Jan-22        Colorado         Denver
#
#                            Address  # Killed  # Injured
# 0                     39 Warren St         0          4
# 1       Fairway St and Suncrest Dr         0          4
# ...

# %%
new=pd.concat([df,df2022])

# %%
new
# Out:
#      Incident ID      Incident Date           State  City Or County  \
# 0         271363  December 29, 2014       Louisiana     New Orleans
# 1         269679  December 27, 2014      California     Los Angeles
# 2         270036  December 27, 2014      California      Sacramento
# 3         269167  December 26, 2014        Illinois  East St. Louis
# 4         268598  December 24, 2014        Missouri     Saint Louis
# ..           ...                ...             ...             ...
# 328      2201641           1-Jan-22       Wisconsin         Kenosha
# 329      2202001           1-Jan-22        Illinois          Peoria
# 330      2201876           1-Jan-22  South Carolina          Dillon
# 331      2201848           1-Jan-22         Indiana      South Bend
# 332      2201677           1-Jan-22        Colorado          Denver
#
#                                  Address  # Killed  # Injured
# 0                    Poydras and Bolivar         0          4
# ...

# %%
new=new.drop_duplicates(subset="Incident ID")

# %%
new
# Out:
#      Incident ID      Incident Date       State    City Or County  \
# 0         271363  December 29, 2014   Louisiana       New Orleans
# 1         269679  December 27, 2014  California       Los Angeles
# 2         270036  December 27, 2014  California        Sacramento
# 3         269167  December 26, 2014    Illinois    East St. Louis
# 4         268598  December 24, 2014    Missouri       Saint Louis
# ..           ...                ...         ...               ...
# 112      2315417          28-May-22     Florida           Malabar
# 113      2315190          28-May-22    Colorado  Colorado Springs
# 114      2315333          28-May-22  California            Merced
# 115      2314951          28-May-22   Tennessee           Memphis
# 136      2354757          13-May-22   Louisiana     Napoleonville
#
#                                  Address  # Killed  # Injured
# 0                    Poydras and Bolivar         0          4
# ...

# %%
df=new[new["Incident Date"].str.contains("-")]
df
# Out:
#      Incident ID Incident Date          State    City Or County  \
# 0        2358329     12-Jul-22  Massachusetts            Boston
# 1        2358053     11-Jul-22    Mississippi           Jackson
# 2        2356813     10-Jul-22          Texas             Alvin
# 3        2356705     10-Jul-22       Illinois        Crest Hill
# 4        2356327     10-Jul-22       Missouri       Kansas City
# ..           ...           ...            ...               ...
# 112      2315417     28-May-22        Florida           Malabar
# 113      2315190     28-May-22       Colorado  Colorado Springs
# 114      2315333     28-May-22     California            Merced
# 115      2314951     28-May-22      Tennessee           Memphis
# 136      2354757     13-May-22      Louisiana     Napoleonville
#
#                             Address  # Killed  # Injured
# 0                      39 Warren St         0          4
# 1        Fairway St and Suncrest Dr         0          4
# ...

# %%
df2022=new[~new["Incident Date"].str.contains("-")]
df2022
# Out:
#       Incident ID      Incident Date       State  City Or County  \
# 0          271363  December 29, 2014   Louisiana     New Orleans
# 1          269679  December 27, 2014  California     Los Angeles
# 2          270036  December 27, 2014  California      Sacramento
# 3          269167  December 26, 2014    Illinois  East St. Louis
# 4          268598  December 24, 2014    Missouri     Saint Louis
# ...           ...                ...         ...             ...
# 3604       274867    January 6, 2015     Florida           Miami
# 3605       273535    January 4, 2015    Virginia         Roanoke
# 3606       273397    January 4, 2015       Texas          Dallas
# 3607       273965    January 2, 2015     Georgia        Savannah
# 3608       272016    January 1, 2015   Tennessee         Memphis
#
#                                   Address  # Killed  # Injured
# 0                     Poydras and Bolivar         0          4
# ...

# %%
df.to_csv("mass_shootings.csv", encoding='utf-8')
df2022.to_csv("2022_mass_shootings.csv", encoding='utf-8')
